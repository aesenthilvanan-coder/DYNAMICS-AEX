# %% [markdown]
# # AEX — adaptive MD analysis
#
# Load `aex_report.json` from completed jobs (`/tmp/caly360_md/<job_id>/`) and compare `error_bounds`, `speedup`, and segment `execution_log`.

# %%
# import json
# from pathlib import Path
# report = json.loads(Path("/tmp/caly360_md/<job_id>/aex_report.json").read_text())
# report.keys()
